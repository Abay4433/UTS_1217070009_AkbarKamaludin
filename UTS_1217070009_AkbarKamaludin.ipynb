# %% [markdown]
# # **UTS PENGOLAHAN CITRA**
#
# Tuliskan kode program dari instruksi yang diperintahkan

# %% [markdown]
# 1. Tuliskan kode program untuk menampilkan gambar dengan library open CV (Poin 5)
#
# Note: Gambar dibebaskan

# %%
import cv2
from google.colab.patches import cv2_imshow

gambar = cv2.imread ('Latarmerah.jpg', cv2.IMREAD_COLOR)

cv2_imshow(gambar)
# Out:
# <PIL.Image.Image image mode=RGB size=617x708>

# %% [markdown]
# 2. Tampilkan tipe data gambar yang disimpan (Poin: 2)

# %%
import cv2
from google.colab.patches import cv2_imshow

gambar = cv2.imread ('Latarmerah.jpg', cv2.IMREAD_COLOR)

tipe_data = gambar.dtype
print (f'Tipe data gambar: {tipe_data}')
# Out:
# Tipe data gambar: uint8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 3.  Cobalah gunakan library Matplotlib untuk menampilkan gambar (Poin: 5)

# %%
import matplotlib.pyplot as plt
import cv2


image = cv2.imread('Latarmerah.jpg')


if image is None:
    print("Error: Unable to load image.")
else:

    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


    plt.imshow(image_rgb)
    plt.axis('on')
    plt.show()

# %% [markdown]
# 4. Buatlah kode program perintah lain yang dapat digunakan untuk mengakses properti citra sepert menampilkan resolusi gambar, menampilkan ukuran data media penyimpan, menampilkan image data type (kedalaman bit) (Poin: 5)

# %%
import cv2

# Membaca gambar
gambar = cv2.imread('Latarmerah.jpg')

# Mendapatkan dimensi gambar (tinggi, lebar)
tinggi, lebar = gambar.shape[:2]

# Menghitung ukuran data gambar (dalam byte)
ukuran_data = gambar.size

# Mendapatkan tipe data gambar
tipe_data = gambar.dtype

# Menampilkan informasi gambar
print(f"Resolusi gambar: {tinggi}x{lebar}")
print(f"Ukuran data: {ukuran_data} bytes")
print(f"Tipe data: {tipe_data}")
# Out:
# Resolusi gambar: 708x617
# Ukuran data: 1310508 bytes
# Tipe data: uint8

# %% [markdown]
# 5. Tuliskan kode program untuk citra dipecah pada band penyusunnya (Poin: 9)

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2

image = cv2.imread('/content/Latarmerah.jpg')

b,g,r = cv2.split(image)
matriks0 = np.zeros(image.shape[:2],image.dtype)
m = matriks0
red = cv2.merge([m,m,r])
cv2_imshow(red)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=617x708>
# -1

# %% [markdown]
# 6. Tampilkan gambar dari channel band biru / Blue Channel, green dan red (Poin: 9)

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/Latarmerah.jpg')

red = img.copy()
red[1,1,1]=0
red[2,2,2]=0
red_shape = red.shape
print('red shape:', red_shape)

green = img.copy()
green[:,:,0]=0
green[:,:,2]=0
green_shape = green.shape
print('green shape:', green_shape)

blue = img.copy()
blue[:,:,0]=0
blue[:,:,1]=0
blue_shape = blue.shape
print('blue shape:', blue_shape)

fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax = ax.ravel()

ax[0].imshow(img)
ax[0].set_title('Original Image')

ax[1].imshow(red)
ax[1].set_title('Red Channel\nShape: {}'.format(red_shape))

ax[2].imshow(green)
ax[2].set_title('Green Channel\nShape: {}'.format(green_shape))

ax[3].imshow(blue)
ax[3].set_title('Blue Channel\nShape: {}'.format(blue_shape))

plt.show()
# Out:
# red shape: (708, 617, 3)
# green shape: (708, 617, 3)
# blue shape: (708, 617, 3)

# %% [markdown]
# 7. Tuliskan kode program untuk konversi BGR dari variable gambar ke colorspace HSV (Poin:5)

# %%
import cv2

img = cv2.imread('Latarmerah.jpg')
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
cv2_imshow(hsv)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=617x708>

# %% [markdown]
# 8. Pisahkan/Pecah hue, saturation dan value (Poin: 10)

# %%
import cv2

# Membaca gambar
image = cv2.imread('Latarmerah.jpg')

# Konversi gambar ke ruang warna HSV
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Memisahkan hue, saturation, dan value
hue = hsv[:,:,0]
saturation = hsv[:,:,1]
value = hsv[:,:,2]

# Menampilkan gambar hue, saturation, dan value
cv2_imshow( hue)
cv2_imshow(saturation)
cv2_imshow(value)

# Menunggu penekanan tombol untuk keluar
cv2.waitKey(0)

# Menutup jendela
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=617x708>
# <PIL.Image.Image image mode=L size=617x708>
# <PIL.Image.Image image mode=L size=617x708>

# %% [markdown]
# 9. Tampilkan gambar hue channel, Saturation, dan Value (Poin 10)

# %%
#menampilkan band hue
import cv2

# Membaca gambar
image = cv2.imread('Latarmerah.jpg')

# Konversi gambar ke ruang warna HSV
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Memisahkan hue, saturation, dan value
hue = hsv[:,:,0]
saturation = hsv[:,:,1]
value = hsv[:,:,2]

# Menampilkan gambar hue, saturation, dan value
cv2_imshow(hue)

# Menunggu penekanan tombol untuk keluar
cv2.waitKey(0)

# Menutup jendela
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=617x708>

# %% [markdown]
# 10. Setelah melakukan konversi BGR ke HSV kemudian tampilkan histogram untuk Band Merah/Red Channel, Hijau/Green Channel dan Biru/Blue channel (boleh menggunakan Matplotlib atau cv2.imshow) (Poin: 10)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('Latarmerah.jpg')

b, g, r = cv2.split(image)

hist_b = cv2.calcHist([b], [0], None, [256], [0,256])
hist_g = cv2.calcHist([g], [0], None, [256], [0,256])
hist_r = cv2.calcHist([r], [0], None, [256], [0,256])

plt.figure(figsize=(10, 6))
plt.plot(hist_r, color='r', label='R')
plt.plot(hist_g, color='g', label='G')
plt.plot(hist_b, color='b', label='B')
plt.title('rgb histogram')
plt.xlabel('intensitas')
plt.ylabel('frequensi')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 11. Tampilkan Histogram untuk channel hue, saturation dan value (poin: 5)

# %%
import cv2
import matplotlib.pyplot as plt

# Membaca gambar
gambar = cv2.imread('Latarmerah.jpg')

# Konversi gambar ke ruang warna HSV
hsv = cv2.cvtColor(gambar, cv2.COLOR_BGR2HSV)

# Memisahkan channel hue, saturation, dan value
h, s, v = cv2.split(hsv)

# Menghitung histogram untuk setiap channel
hist_hue = cv2.calcHist([h], [0], None, [256], [0, 256])
hist_saturation = cv2.calcHist([s], [0], None, [256], [0, 256])
hist_value = cv2.calcHist([v], [0], None, [256], [0, 256])

# Menampilkan histogram
plt.figure(figsize=(10, 6))
plt.plot(hist_hue, color='r', label='H')
plt.plot(hist_saturation, color='g', label='S')
plt.plot(hist_value, color='b', label='V')
plt.title('HSV histogram')
plt.xlabel('intensitas')
plt.ylabel('frequensi')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 12. Menaikan brighness dengan menambahkan nilai konstanta = 100. Tampilkan gambar sebelum brightness dan sesudah (poin: 10)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


gambar = cv2.imread("Latarmerah.jpg")
tinggi_gambar = gambar.shape[0]
lebar_gambar = gambar.shape [1]
channel_gambar = gambar.shape [2]
tipe_gambar = gambar.dtype

brightness_gambar = np.zeros(gambar.shape, dtype=np.uint8)
def brighter (nilai):
  for y in range(0, tinggi_gambar):
    for x in range (0, lebar_gambar):
      red = gambar[y][x][0]
      green = gambar [y][x][1]
      blue = gambar [y][x][2]
      gray = (int(red) + int (green) + int (blue)) /3
      gray+= nilai

      if gray > 255:
        gray = 255
      if gray < 0:
        gray = 0

      brightness_gambar [y][x] = (gray, gray, gray)

brighter(0)
plt.imshow (brightness_gambar)
plt.title("Brightness 0")
plt.show()

brighter(100)
plt.imshow (brightness_gambar)
plt.title("Brightness 100")
plt.show()

# %% [markdown]
# 13. Putar gambar 90 derajat dan tampilkan (poin:10)

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image = cv2.imread('/content/Latarmerah.jpg')

(height, width) = image.shape[0:2]
RotasiMatriks = cv2.getRotationMatrix2D((width/2, height/2),-90,0.5)

RotasiCitra = cv2.warpAffine (image, RotasiMatriks, (width, height))
cv2_imshow(RotasiCitra)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=617x708>
# -1

# %% [markdown]
# 13. Normalisasikan gambar dan tampilkan historgramnya (poin 5)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# fungsi untuk menampilkan gambar menggunakan matplotlib
def show_image(image,title='image',cmap_type='gray'):
    plt.figure()
    plt.imshow(image,cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()

# Fungsi untuk menghitung distribusi probabilitas(normalisasi histogram)
def calculate_normalized_histogram(image):
    # hitung histogram
    histogram,_=np.histogram(image, bins=256, range=(0,256))

    # hitung jumlah total pixel
    total_pixels=image.size

    #Hitung distribusi probabilitas dengan rumus ni/N
    normalized_histogram = histogram / total_pixels

    return normalized_histogram
# baca citra dari file menggunakan opencv
image_path = 'Latarmerah.jpg'
image = cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)

# tampilkan citra asli
show_image(image,title='Normalisasi Citra')

# hitung distribusi probabilitas
normalized_histogram = calculate_normalized_histogram(image)

# plot histogram citra asli dengan distribusi probabilitas
plt.figure()
plt.bar(range(256),normalized_histogram,color='black')
plt.title('Normalisasi Histogram Citra')
plt.xlabel('Intensitas Pixel')
plt.ylabel('Distribusi Probabilitas')
plt.show()
